# %% [markdown]
# # Notebook to explore data
#
# Data are downloaded from:
# - https://data.iledefrance-mobilites.fr/explore/dataset/traces-des-lignes-de-transport-en-commun-idfm/information/
# - https://data.iledefrance-mobilites.fr/explore/dataset/arrets-lignes/information

# %%
import pandas as pd
import geopandas as gpd
import sys

sys.path.append("../")    # Add the path to the root directory (where we can find the folder narval/)

# %load_ext autoreload
# %autoreload 2 

from src.geoplotter import GeoPlotter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Lines
# ### Explore the csv file

# %%
df = pd.read_csv("../data/traces-des-lignes-de-transport-en-commun-idfm.csv", sep=";")

# %%
df.head()
# Out:
#             ID Short Name Long Name Route Type   Color  Route URL  \
# 0  IDFM:C00029        502       502        Bus  FBE324        NaN
# 1  IDFM:C00324          1         1        Bus  8CE39C        NaN
# 2  IDFM:C00527       6183      6183        Bus  640082        NaN
# 3  IDFM:C00582       4111      4111        Bus  0055C8        NaN
# 4  IDFM:C02300        469       469        Bus  F9BD1B        NaN
#
#                                                Shape id_ilico  \
# 0  {"coordinates": [[[2.699703778822941, 48.75681...   C00029
# 1  {"coordinates": [[[2.1731170740829633, 48.8869...   C00324
# 2  {"coordinates": [[[2.037543395919414, 48.70702...   C00527
# 3  {"coordinates": [[[2.5339731652683914, 48.6812...   C00582
# 4  {"coordinates": [[[2.206319892171782, 48.80944...   C02300
#
#                             OperatorName                    NetworkName  \
# 0  Keolis Grand Paris Vallée de la Marne                  Marne et Brie
# 1     Keolis Argenteuil Boucles de Seine  Argenteuil - Boucles de Seine
# 2      Keolis Vélizy Vallée de la Bièvre                 Vélizy Vallées
# 3       Keolis Val d'Yerres Val de Seine      Val d'Yerres Val de Seine
# 4                               Mobicité        Grand Paris Seine Ouest
#
#    ID_Bus_Contrat                                                URL  \
# 0             NaN  https://ilico.iledefrance-mobilites.fr/uploads...
# 1            33.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 2            27.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 3            20.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 4             NaN  https://ilico.iledefrance-mobilites.fr/uploads...
#
#   long_name_first                           geo_point_2d
# 0               5   48.78052649649789, 2.649521051884891
# 1               1   48.8979441061215, 2.1225993978069213
# 2               6  48.72786292084329, 2.0875909447544836
# 3               4  48.698405147944825, 2.519626179019192
# 4               4  48.81941951166231, 2.1946329048115545

# %%
df['Route Type'].value_counts()
# Out:
# Route Type
# Bus          1952
# Rail           24
# Tram           17
# Subway         16
# CableWay        1
# Funicular       1
# Name: count, dtype: int64

# %%
df.query("`Route Type` == 'Tram'").loc[:, 'Long Name'].unique()
# Out:
# <ArrowStringArray>
# [     'T6',      'T1',      'T2',     'T12',      'T4',     'T11',      'T8',
#  'CDG VAL', 'ORLYVAL',     'T3b',     'T3a',     'T14',      'T9',      'T5',
#       'T7',     'T13',     'T10']
# Length: 17, dtype: str

# %%
df.query("`Route Type` == 'Subway'").loc[:, 'Long Name'].unique()
# Out:
# <ArrowStringArray>
# [ '2', '3B', '13',  '8', '14', '7B',  '7',  '4',  '5',  '6',  '9', '10', '11',
#   '1',  '3', '12']
# Length: 16, dtype: str

# %%
df.query("`Long Name` == '14'")
# Out:
#                ID Short Name Long Name Route Type   Color  Route URL  \
# 463   IDFM:C01384         14        14     Subway  62259D        NaN
# 1646  IDFM:C00350         14        14        Bus  0055FA        NaN
#
#                                                   Shape id_ilico  \
# 463   {"coordinates": [[[2.3625135570893536, 48.7276...   C01384
# 1646  {"coordinates": [[[2.302883562195881, 48.76224...   C00350
#
#              OperatorName             NetworkName  ID_Bus_Contrat  \
# 463                  RATP                     NaN             NaN
# 1646  Transdev Vallée Sud  Vallée Grand Sud Paris             NaN
#
#                                                     URL long_name_first  \
# 463   https://www.ratp.fr/sites/default/files/lines-...               1
# 1646  https://www.valleesudbus.fr/api/1.0/timetablef...               1
#
#                                geo_point_2d
# 463   48.83092438720487, 2.3516250943849584
# 1646    48.7763796509796, 2.277356359793636

# %% [markdown]
# ### Explore the geojson file

# %%
gdf = gpd.read_file("../data/traces-des-lignes-de-transport-en-commun-idfm.geojson")

# %%
gdf.head()
# Out:
#       route_id route_short_name route_long_name route_type route_color  \
# 0  IDFM:C00971             4570            4570        Bus      DC9600
# 1  IDFM:C00137             5211            5211        Bus      9B993B
# 2  IDFM:C01147              118             118        Bus      DC9600
# 3  IDFM:C00007              282             282        Bus      82DC73
# 4  IDFM:C00168             5208            5208        Bus      008C5A
#
#   route_url shape id_ilico               operatorname             networkname  \
# 0      None  None   C00971      Transdev Cœur Essonne          Cœur d’Essonne
# 1      None  None   C00137      Transdev Sud Yvelines  Centre et Sud Yvelines
# 2      None  None   C01147  RATP Cap Boucles de Marne           Bord de Marne
# 3      None  None   C00007  Keolis Ouest Val-de-Marne        Seine Grand Orly
# 4      None  None   C00168      Transdev Sud Yvelines  Centre et Sud Yvelines
#
#    id_bus_contrat                                                url  \
# 0            25.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 1            30.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 2             NaN  https://ilico.iledefrance-mobilites.fr/uploads...
# 3            22.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 4            30.0  https://ilico.iledefrance-mobilites.fr/uploads...
#
#   long_name_first                                       geo_point_2d  \
# 0               4  {'lon': 2.1929646597449444, 'lat': 48.59042525...
# 1               5  {'lon': 1.9621000780350604, 'lat': 48.88908768...
# 2               1  {'lon': 2.4618231699131994, 'lat': 48.85070495...
# 3               2  {'lon': 2.4084247006650354, 'lat': 48.77426758...
# 4               5  {'lon': 1.859907739581182, 'lat': 48.670795228...
#
#                                             geometry
# 0  MULTILINESTRING ((2.18505 48.59499, 2.18887 48...
# 1  MULTILINESTRING ((1.9484 48.86589, 1.98131 48....
# 2  MULTILINESTRING ((2.48841 48.85401, 2.48549 48...
# 3  MULTILINESTRING ((2.39004 48.75495, 2.39423 48...
# 4  MULTILINESTRING ((1.88446 48.70101, 1.88713 48...

# %%
gdf['route_type'].value_counts()
# Out:
# route_type
# Bus          1951
# Rail           24
# Tram           17
# Subway         16
# CableWay        1
# Funicular       1
# Name: count, dtype: int64

# %%
gdf['route_long_name'].unique()
# Out:
# <ArrowStringArray>
# [                   '4570',                    '5211',
#                      '118',                     '282',
#                     '5208',                       '8',
#                     '3262',                    '3215',
#                     '2220',                    '5438',
#  ...
#                     '6550',                    '6578',
#                     '6582',                    '4666',
#                     '4673',                'TàD 4343',
#  'TUVIM Ile Saint-Germain',                    '9514',
#                      '240',                    '9517']
# Length: 1895, dtype: str

# %%
gdf.query("`route_type` == 'Subway'").loc[:, 'route_long_name'].unique()
# Out:
# <ArrowStringArray>
# ['3B',  '7',  '8', '11',  '1',  '5', '7B', '13', '10', '14',  '4',  '2',  '3',
#   '6',  '9', '12']
# Length: 16, dtype: str

# %%
gdf.query("`route_long_name` == '14'")
# Out:
#          route_id route_short_name route_long_name route_type route_color  \
# 1245  IDFM:C00350               14              14        Bus      0055FA
# 1298  IDFM:C01384               14              14     Subway      62259D
#
#      route_url shape id_ilico         operatorname             networkname  \
# 1245      None  None   C00350  Transdev Vallée Sud  Vallée Grand Sud Paris
# 1298      None  None   C01384                 RATP                     NaN
#
#       id_bus_contrat                                                url  \
# 1245             NaN  https://www.valleesudbus.fr/api/1.0/timetablef...
# 1298             NaN  https://www.ratp.fr/sites/default/files/lines-...
#
#      long_name_first                                       geo_point_2d  \
# 1245               1  {'lon': 2.277356359793636, 'lat': 48.776379650...
# 1298               1  {'lon': 2.3516250943849584, 'lat': 48.83092438...
#
#                                                geometry
# 1245  MULTILINESTRING ((2.27306 48.79382, 2.27183 48...
# 1298  MULTILINESTRING ((2.36251 48.72766, 2.37247 48...

# %%
gdf.crs.to_epsg()
# Out:
# 4326

# %%
gdf.geometry.isna().sum()
# Out:
# np.int64(3)

# %%
gdf[gdf.geometry.isna()]
# Out:
#          route_id route_short_name  route_long_name route_type route_color  \
# 734   IDFM:C02383         TàD 4596         TàD 4596        Bus      FFBE00
# 775   IDFM:C02640             Soir  Soir Saint-Rémy        Bus      652C8F
# 1542  IDFM:C02460         TàD 4597         TàD 4597        Bus      FFBE00
#
#      route_url shape id_ilico           operatorname             networkname  \
# 734       None  None   C02383  Transdev Cœur Essonne          Cœur d’Essonne
# 775       None  None   C02640  Transdev Sud Yvelines  Centre et Sud Yvelines
# 1542      None  None   C02460  Transdev Cœur Essonne          Cœur d’Essonne
#
#       id_bus_contrat                                                url  \
# 734             25.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 775             30.0  https://ilico.iledefrance-mobilites.fr/uploads...
# 1542            25.0  https://ilico.iledefrance-mobilites.fr/uploads...
#
#      long_name_first geo_point_2d geometry
# 734                T          NaN     None
# 775                S          NaN     None
# 1542               T          NaN     None

# %%
geoplotter = GeoPlotter(gdf, geom_col="geometry")
geoplotter.add_geodata_to_map()
geoplotter.map

# %%
gdf_tmp = gdf.query("`route_long_name` == '14'")

geoplotter_2 = GeoPlotter(gdf_tmp, geom_col="geometry", tiles="Cartodb Positron")
geoplotter_2.add_geodata_to_map()
geoplotter_2.map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce5a32386937dc08a727a75da49b8b29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce5a32386937dc08a727a75da49b8b29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce5a32386937dc08a727a75da49b8b29 = L.map(
#                 &quot;map_ce5a32386937dc08a727a75da49b8b29&quot;,
#                 {
#                     center: [48.80216785244995, 2.3143300475770916],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f597538784748922799af1499e3647b6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f597538784748922799af1499e3647b6.addTo(map_ce5a32386937dc08a727a75da49b8b29);
#
#
#             var poly_line_def46b810388921d0e54873a1782ad6d = L.polyline(
#                 [[48.79382469907371, 2.273057467725075], [48.790147625002476, 2.2718291671509943], [48.788386365317336, 2.2706150911585805], [48.78755956532545, 2.2677818663182783], [48.78829645577194, 2.264749749761512], [48.78702328979935, 2.2610245909736197], [48.785980815622295, 2.261161854433015], [48.7863253603266, 2.26598891229917], [48.786375605156955, 2.269785701130181], [48.78559386718051, 2.2728590908171733], [48.784670050425284, 2.2747638439621847], [48.782627719607675, 2.274656128447308], [48.78014667001005, 2.277848009158129], [48.77933249515191, 2.280050363985275], [48.777609216379794, 2.2761820233894983], [48.77641852344917, 2.274130047897247], [48.775108307904084, 2.271657979953459], [48.77466732643847, 2.2686703657891862], [48.77350965897154, 2.267625184277399], [48.769912802860375, 2.2721795054006826], [48.77044561453114, 2.275492166886031], [48.77026779683722, 2.28029786355424], [48.76689929299147, 2.279527949318624], [48.765853662270025, 2.2851343333584166], [48.76621717231675, 2.2902859561682627], [48.76229117826118, 2.2910467809496096], [48.76157840311507, 2.299817815027778], [48.76224392736852, 2.302883562195881]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ce5a32386937dc08a727a75da49b8b29);
#
#
#             poly_line_def46b810388921d0e54873a1782ad6d.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;route_id:&lt;/b&gt; IDFM:C00350&lt;br&gt;&lt;b&gt;route_short_name:&lt;/b&gt; 14&lt;br&gt;&lt;b&gt;route_long_name:&lt;/b&gt; 14&lt;br&gt;&lt;b&gt;route_type:&lt;/b&gt; Bus&lt;br&gt;&lt;b&gt;route_color:&lt;/b&gt; 0055FA&lt;br&gt;&lt;b&gt;route_url:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;shape:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;id_ilico:&lt;/b&gt; C00350&lt;br&gt;&lt;b&gt;operatorname:&lt;/b&gt; Transdev Vallée Sud&lt;br&gt;&lt;b&gt;networkname:&lt;/b&gt; Vallée Grand Sud Paris&lt;br&gt;&lt;b&gt;id_bus_contrat:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;url:&lt;/b&gt; https://www.valleesudbus.fr/api/1.0/timetablefile/860414840/raw/fh_14_vsgp_hiv_24-25_web.pdf&lt;br&gt;&lt;b&gt;long_name_first:&lt;/b&gt; 1&lt;br&gt;&lt;b&gt;geo_point_2d:&lt;/b&gt; {&#x27;lon&#x27;: 2.277356359793636, &#x27;lat&#x27;: 48.7763796509796}
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_3d2b9684d70966db3b7e7e427688428c = L.polyline(
#                 [[48.76224392736852, 2.302883562195881], [48.762164263588055, 2.3000276326487215], [48.76154925948609, 2.2903086045287147], [48.76425066722745, 2.287809319037509], [48.76594400500005, 2.2852011247942983], [48.76737775602034, 2.2798206797661176], [48.77058445512957, 2.280606457115133], [48.7729435405658, 2.2810365970973216], [48.77287103300825, 2.277962288436097], [48.77289160113349, 2.2754173892087333], [48.77472594954157, 2.269431595402386], [48.77510880561998, 2.2717396219139956], [48.776437667695106, 2.274320300530046], [48.77779106377094, 2.276506113389422], [48.779965069668805, 2.2805451845906304], [48.781904947669084, 2.2800693113371406], [48.78433423321206, 2.277232021095703], [48.785866485888796, 2.2777688449006415], [48.78604348561587, 2.2758064116271397], [48.78568404958562, 2.2728986

# %%
route_type_colors = {
    "Bus":       "#888888",
    "CableWay":  "#9B59B6",
    "Funicular": "#E67E22",
    "Rail":      "#2471A3",
    "Subway":    "#E74C3C",
    "Tram":      "#27AE60",
}

geoplotter_all = GeoPlotter(gdf, geom_col="geometry", tiles="Cartodb Positron")
geoplotter_all.add_geodata_to_map(
    color_col="route_type",
    colormap=route_type_colors,
    tooltip_cols=["route_short_name", "route_long_name", "route_type", "operatorname"],
)
geoplotter_all.map

# %% [markdown]
# ## Stops

# %% [markdown]
# ### Explore the geojson file

# %%
gdf_stops = gpd.read_file("../data/arrets-lignes.geojson")

# %%
gdf_stops.head()
# Out:
#             id route_long_name     stop_id              stop_name  \
# 0  IDFM:C02146              S4  IDFM:32369               3 Buttes
# 1  IDFM:C02146              S4  IDFM:32047  Collège des Amandiers
# 2  IDFM:C02147              S7  IDFM:32123  Lycée Evariste Galois
# 3  IDFM:C02148              S1   IDFM:5387   Gare de Sartrouville
# 4  IDFM:C02148              S1  IDFM:32339              Cimetière
#
#              stop_lon            stop_lat                        operatorname  \
# 0  2.1878687431344748   48.90911535912226  Keolis Argenteuil Boucles de Seine
# 1  2.1955750900476927   48.91190130211384  Keolis Argenteuil Boucles de Seine
# 2  2.1634990760259556   48.92880465181998  Keolis Argenteuil Boucles de Seine
# 3  2.1578119645908873   48.93781186755499  Keolis Argenteuil Boucles de Seine
# 4  2.1460387415274402  48.911576403475294  Keolis Argenteuil Boucles de Seine
#
#   shortname bookingrules mode          nom_commune code_insee  \
# 0        S4          NaN  Bus  Carrières-sur-Seine      78124
# 1        S4          NaN  Bus  Carrières-sur-Seine      78124
# 2        S7          NaN  Bus         Sartrouville      78586
# 3        S1          NaN  Bus         Sartrouville      78586
# 4        S1          NaN  Bus            Montesson      78418
#
#                    geometry
# 0  POINT (2.18787 48.90912)
# 1   POINT (2.19558 48.9119)
# 2    POINT (2.1635 48.9288)
# 3  POINT (2.15781 48.93781)
# 4  POINT (2.14604 48.91158)

# %%
gdf_stops['route_long_name'].unique()
# Out:
# <ArrowStringArray>
# [                       'S4',                        'S7',
#                         'S1',                         'B',
#                          'F',                        'S5',
#                          'P',                        'S2',
#                       '2426',                      '4615',
#  ...
#                       '7821',                      '7822',
#                       '2169',                      '3458',
#  'Soir Gretz-Armainvilliers',    'Soir Ozoir-la-Ferrière',
#           'Soir Rambouillet',                      '4455',
#                   'TàD 4596',     'A04 Paris La Villette']
# Length: 1908, dtype: str

# %%
gdf_stops['mode'].value_counts()
# Out:
# mode
# Bus             71728
# Metro             805
# Tramway           541
# LocalTrain        263
# RapidTransit      254
# regionalRail      150
# RailShuttle        16
# CableWay           10
# Funicular           4
# Name: count, dtype: int64

# %%
gdf_stops.query("mode=='LocalTrain'").head()
# Out:
#                id route_long_name                         stop_id  \
# 5376  IDFM:C01730               P   IDFM:monomodalStopPlace:47184
# 5377  IDFM:C01730               P  IDFM:monomodalStopPlace:411375
# 5378  IDFM:C01730               P   IDFM:monomodalStopPlace:47322
# 5379  IDFM:C01730               P   IDFM:monomodalStopPlace:43161
# 5380  IDFM:C01730               P   IDFM:monomodalStopPlace:43246
#
#                   stop_name            stop_lon            stop_lat  \
# 5376                Mormant    2.88807855133882   48.61409277056721
# 5377      Mareuil-sur-Ourcq  3.0754989980809686  49.135381005893805
# 5378                  Esbly   2.809640025507793  48.902895083058525
# 5379                  Meaux  2.8733082321502925    48.9566203252873
# 5380  La Ferté-sous-Jouarre   3.124704606439104   48.95078183142266
#
#      operatorname shortname bookingrules        mode            nom_commune  \
# 5376         SNCF         P          NaN  LocalTrain                Mormant
# 5377         SNCF         P          NaN  LocalTrain      Mareuil-sur-Ourcq
# 5378         SNCF         P          NaN  LocalTrain                  Esbly
# 5379         SNCF         P          NaN  LocalTrain                  Meaux
# 5380         SNCF         P          NaN  LocalTrain  La Ferté-sous-Jouarre
#
#      code_insee                  geometry
# 5376      77317  POINT (2.88808 48.61409)
# 5377      60380   POINT (3.0755 49.13538)
# 5378      77171   POINT (2.80964 48.9029)
# 5379      77284  POINT (2.87331 48.95662)
# 5380      77183   POINT (3.1247 48.95078)

# %%
gdf['route_type'].value_counts()
# Out:
# route_type
# Bus          1951
# Rail           24
# Tram           17
# Subway         16
# CableWay        1
# Funicular       1
# Name: count, dtype: int64

# %%
gdf_tmp = gdf_stops.query("`route_long_name` == '14'")

geoplotter_3 = GeoPlotter(gdf_tmp, geom_col="geometry", tiles="Cartodb Positron")
geoplotter_3.add_geodata_to_map()
geoplotter_3.map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07890f5374a88becbc25c57f6598b00f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07890f5374a88becbc25c57f6598b00f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07890f5374a88becbc25c57f6598b00f = L.map(
#                 &quot;map_07890f5374a88becbc25c57f6598b00f&quot;,
#                 {
#                     center: [48.80409855693137, 2.3081155847619272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98a249ee28490615968954b3a8844e0e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98a249ee28490615968954b3a8844e0e.addTo(map_07890f5374a88becbc25c57f6598b00f);
#
#
#             var circle_449ff504de1546cd737ce9d6c58447b3 = L.circle(
#                 [48.74684479207573, 2.372466241689093],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07890f5374a88becbc25c57f6598b00f);
#
#
#             circle_449ff504de1546cd737ce9d6c58447b3.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;id:&lt;/b&gt; IDFM:C01384&lt;br&gt;&lt;b&gt;route_long_name:&lt;/b&gt; 14&lt;br&gt;&lt;b&gt;stop_id:&lt;/b&gt; IDFM:490852&lt;br&gt;&lt;b&gt;stop_name:&lt;/b&gt; Thiais - Orly (Pont de Rungis)&lt;br&gt;&lt;b&gt;stop_lon:&lt;/b&gt; 2.372466241689093&lt;br&gt;&lt;b&gt;stop_lat:&lt;/b&gt; 48.74684479207573&lt;br&gt;&lt;b&gt;operatorname:&lt;/b&gt; RATP&lt;br&gt;&lt;b&gt;shortname:&lt;/b&gt; 14&lt;br&gt;&lt;b&gt;bookingrules:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;mode:&lt;/b&gt; Metro&lt;br&gt;&lt;b&gt;nom_commune:&lt;/b&gt; Thiais&lt;br&gt;&lt;b&gt;code_insee:&lt;/b&gt; 94073
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_16329eb957dbe5edee727b5eba32ca51 = L.circle(
#                 [48.80994448106093, 2.350014950529505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07890f5374a88becbc25c57f6598b00f);
#
#
#             circle_16329eb957dbe5edee727b5eba32ca51.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;id:&lt;/b&gt; IDFM:C01384&lt;br&gt;&lt;b&gt;route_long_name:&lt;/b&gt; 14&lt;br&gt;&lt;b&gt;stop_id:&lt;/b&gt; IDFM:490849&lt;br&gt;&lt;b&gt;stop_name:&lt;/b&gt; Hôpital Bicêtre&lt;br&gt;&lt;b&gt;stop_lon:&lt;/b&gt; 2.350014950529505&lt;br&gt;&lt;b&gt;stop_lat:&lt;/b&gt; 48.80994448106093&lt;br&gt;&lt;b&gt;operatorname:&lt;/b&gt; RATP&lt;br&gt;&lt;b&gt;shortname:&lt;/b&gt; 14&lt;br&gt;&lt;b&gt;bookingrules:&lt;/b&gt; nan&lt;br&gt;&lt;b&gt;mode:&lt;/b&gt; Metro&lt;br&gt;&lt;b&gt;nom_commune:&lt;/b&gt; Le Kremlin-Bicêtre&lt;br&gt;&lt;b&gt;code_insee:&lt;/b&gt; 94043
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_fb8d4b582066a551bd595a1e9011c7b1 = L.circle(
#                 [48.82119024728473, 2.358986576752596],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_07890f5374a88becbc25c57f6598b00f);
#
#
#             circle_fb8d4b582066a551bd595a1e9011c7b1.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;id:&lt;/b&

# %% [markdown]
# Use rather the line ``id``

# %%
gdf_stops["id"].unique()
# Out:
# <ArrowStringArray>
# ['IDFM:C02146', 'IDFM:C02147', 'IDFM:C02148', 'IDFM:C02149', 'IDFM:C02150',
#  'IDFM:C02151', 'IDFM:C02152', 'IDFM:C02153', 'IDFM:C02154', 'IDFM:C02155',
#  ...
#  'IDFM:C00753', 'IDFM:C00754', 'IDFM:C00660', 'IDFM:C01008', 'IDFM:C02522',
#  'IDFM:C02523', 'IDFM:C02641', 'IDFM:C02453', 'IDFM:C02383', 'IDFM:C02723']
# Length: 2009, dtype: str

# %%
gdf["route_id"].unique()
# Out:
# <ArrowStringArray>
# ['IDFM:C00971', 'IDFM:C00137', 'IDFM:C01147', 'IDFM:C00007', 'IDFM:C00168',
#  'IDFM:C01717', 'IDFM:C01502', 'IDFM:C01503', 'IDFM:C00634', 'IDFM:C00755',
#  ...
#  'IDFM:C02811', 'IDFM:C02813', 'IDFM:C02823', 'IDFM:C02827', 'IDFM:C02830',
#  'IDFM:C02834', 'IDFM:C02835', 'IDFM:C01741', 'IDFM:C01743', 'IDFM:C01738']
# Length: 2010, dtype: str

# %% [markdown]
# Compare the lines that are listed in the 2 files
# $\rightarrow$ only a few discrepancies, let's ignore those lines

# %%
for x in gdf_stops["id"].unique().tolist():
    if x not in gdf["route_id"].unique().tolist():
        print(f"{x} is not in gdf")
# Out:
# IDFM:C02442 is not in gdf
# IDFM:C02019 is not in gdf
# IDFM:C02636 is not in gdf
# IDFM:C02852 is not in gdf
# IDFM:C02492 is not in gdf
# IDFM:C01683 is not in gdf
# IDFM:C02712 is not in gdf

# %%
for x in gdf["route_id"].unique().tolist():
    if x not in gdf_stops["id"].unique().tolist():
        print(f"{x} is not in gdf_stops")
# Out:
# IDFM:C01300 is not in gdf_stops
# IDFM:C02494 is not in gdf_stops
# IDFM:C02677 is not in gdf_stops
# IDFM:C01266 is not in gdf_stops
# IDFM:C02590 is not in gdf_stops
# IDFM:C01617 is not in gdf_stops
# IDFM:C02679 is not in gdf_stops
# IDFM:C02734 is not in gdf_stops

# %% [markdown]
# ## Accessibility data
#
# ### Bus stops — `sdap-arrets-associes.csv`

# %%
df_access_1 = pd.read_csv("../data/sdap-arrets-associes.csv", sep=";")
df_access_1.head()
# Out:
#       route_id route_long_name     stop_id  \
# 0  IDFM:C01076              26  IDFM:29421
# 1  IDFM:C01079              29  IDFM:36096
# 2  IDFM:C01080              30  IDFM:29453
# 3  IDFM:C01081              31  IDFM:39720
# 4  IDFM:C01081              31  IDFM:27486
#
#                              stop_name OperatorName    ArRTown  \
# 0                                Ramus         RATP  Paris 20e
# 1                     Picpus - Reuilly         RATP  Paris 12e
# 2  Charles de Gaulle - Étoile - Kléber         RATP  Paris 16e
# 3      Jouffroy d'Abbans - Tocqueville         RATP  Paris 17e
# 4                Duhesme - Le Ruisseau         RATP  Paris 18e
#
#    ArRPostalRegion                           stop_Geopoint  ArRXEpsg2154  \
# 0          75120.0    48.86207311861907, 2.400207153710905      655996.0
# 1          75112.0  48.839540194852965, 2.3993764732901233      655916.0
# 2          75116.0    48.87267325194884, 2.294111691155133      648223.0
# 3          75117.0      48.886140878172, 2.310320941501316      649425.0
# 4          75118.0   48.89290617182383, 2.3410824143455264      651687.0
#
#    ArRYEpsg2154 shortName bookingRules mode  \
# 0     6862616.0        26          NaN  Bus
# 1     6860111.0        29          NaN  Bus
# 2     6863859.0        30          NaN  Bus
# 3     6865346.0        31          NaN  Bus
# 4     6866079.0        31          NaN  Bus
#
#                                 Pointgeo Nom_commune  Code_insee  \
# 0   48.86207311863272, 2.400207153710905       Paris       75056
# 1  48.83954019486667, 2.3993764732901237       Paris       75056
# 2  48.87267325196247, 2.2941116911551336       Paris       75056
# 3    48.8861408781856, 2.310320941501316       Paris       75056
# 4  48.892906171837424, 2.341082414345527       Paris       75056
#
#                                           Extensions ArRAccessibility  \
# 0  {"ServiceFacilitySet": {"@id": "FR1:ServiceFac...             true
# 1  {"ServiceFacilitySet": {"@id": "FR1:ServiceFac...             true
# 2  {"ServiceFacilitySet": {"@id": "FR1:ServiceFac...             true
# 3  {"ServiceFacilitySet": {"@id": "FR1:ServiceFac...             true
# 4  {"ServiceFacilitySet": {"@id": "FR1:ServiceFac...             true
#
#   ArRAudibleSignals ArRVisualSigns
# 0             false           true
# 1           unknown        unknown
# 2           unknown        unknown
# 3           unknown        unknown
# 4           unknown        unknown

# %%
print(f"Rows: {len(df_access_1)} — Unique stop_ids: {df_access_1['stop_id'].nunique()}")
df_access_1["ArRAccessibility"].value_counts(dropna=False)
# Out:
# Rows: 37337 — Unique stop_ids: 22613
# ArRAccessibility
# true       23260
# false       8121
# partial     5739
# unknown      215
# NaN            2
# Name: count, dtype: int64

# %%
df_access_1.drop_duplicates(subset="stop_id")["ArRAccessibility"].value_counts(dropna=False)
# Out:
# ArRAccessibility
# true       13713
# false       6083
# partial     2658
# unknown      157
# NaN            2
# Name: count, dtype: int64

# %% [markdown]
# ### Train/RER stations — `accessibilite-en-gare.csv`

# %%
df_access_2 = pd.read_csv("../data/accessibilite-en-gare.csv", sep=";")
df_access_2.head()
# Out:
#                                stop_point_id  accessibility_level_id  \
# 0   stop_point:IDFM:monomodalStopPlace:47915                       1
# 1  stop_point:IDFM:monomodalStopPlace:462398                       3
# 2   stop_point:IDFM:monomodalStopPlace:47923                       3
# 3   stop_point:IDFM:monomodalStopPlace:46801                       1
# 4   stop_point:IDFM:monomodalStopPlace:43094                       4
#
#                             accessibility_level_name commentaire  \
# 0                       gare ou arrêt non accessible         NaN
# 1  train accessible sur réservation préalable aup...         NaN
# 2  train accessible sur réservation préalable aup...         NaN
# 3                       gare ou arrêt non accessible         NaN
# 4  train accessible sur demande auprès d'un agent...         NaN
#
#                            stop_name                    stop_point_geopoint
# 0              Achères Grand Cormier  48.95541092942684, 2.0936529195192275
# 1  Aéroport CDG 1 (Terminal 3) - RER  49.00979397116337, 2.5614121946317394
# 2                 Bécon les Bruyères   48.90549079769296, 2.268790065027107
# 3                  Boissy-l'Aillerie   49.07572135804642, 2.025386064104548
# 4                 Boissy-Saint-Léger  48.752267307821874, 2.504498176690716

# %%
print(f"Rows: {len(df_access_2)} — Unique stop_point_ids: {df_access_2['stop_point_id'].nunique()}")
df_access_2["accessibility_level_name"].value_counts(dropna=False)
# Out:
# Rows: 459 — Unique stop_point_ids: 459
# accessibility_level_name
# gare ou arrêt non accessible                                                 213
# train accessible sur réservation préalable auprès du service AssistenGare    174
# train accessible sur demande auprès d'un agent en station                     58
# véhicule accessible en toute autonomie                                        14
# Name: count, dtype: int64

# %%
df_access_2[["accessibility_level_id", "accessibility_level_name"]].drop_duplicates()
# Out:
#     accessibility_level_id                           accessibility_level_name
# 0                        1                       gare ou arrêt non accessible
# 1                        3  train accessible sur réservation préalable aup...
# 4                        4  train accessible sur demande auprès d'un agent...
# 20                       6             véhicule accessible en toute autonomie

# %% [markdown]
# #### Join with `gdf_stops` — why SNCF stop count differs
#
# `accessibilite-en-gare.csv` uses `stop_point:IDFM:monomodalStopPlace:XXXXX` as identifier.
# Strip `stop_point:` to match `stop_id` in `arrets-lignes.geojson`.

# %%
print(f"Number of SNCF stops in gdf_stops = {gdf_stops.query("operatorname=='SNCF'")['stop_id'].nunique()}")
print(f"Number of stops in df_access_2 = {df_access_2['stop_point_id'].nunique()}")
# Out:
# Number of SNCF stops in gdf_stops = 1202
# Number of stops in df_access_2 = 459

# %%
sncf_stops = gdf_stops[gdf_stops["operatorname"] == "SNCF"].copy()

df_access_2_norm = df_access_2.copy()
df_access_2_norm["stop_id"] = df_access_2_norm["stop_point_id"].str.replace("stop_point:", "", regex=False)

merged = sncf_stops.merge(
    df_access_2_norm[["stop_id", "accessibility_level_name"]],
    on="stop_id",
    how="left",
    indicator=True,
)
merged["matched"] = merged["_merge"] == "both"

# Mode distribution: matched vs unmatched explains the count discrepancy
merged.groupby(["mode", "matched"]).size().unstack(fill_value=0).rename(
    columns={True: "matched", False: "unmatched"}
)
# Out:
# matched       unmatched  matched
# mode
# Bus                 765        0
# LocalTrain            3      260
# RapidTransit          0      254
# regionalRail         96       54
